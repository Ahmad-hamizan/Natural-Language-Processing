# %% [markdown]
# sebelum mengerjakan Quiz, isi terlebih dahulu bagian identitas anda di bawah ini.
#
# Saya
#
# **Nama**: Ahmad Hamizan
#
# **NIM**: 0110224163
#
# **berjanji** untuk mengerjakan Tugas ini secara mandiri. Apabila saya mencontek atau memberikan contekan maka adalah pokoknya (cukup anda dan Allah yang tau)

# %% [markdown]
# ### **Variabel dan Tipe Data**

# %%
name = "Romi Wahyudi"
age = 21
height = 165
weight = 64.6
is_student = True

# %% [markdown]
# ### **Tipe Data Collection**

# %%
# List
friends = ["Romi", "Wahyudi", "Hasibuan"]
variabel_with_list = [name, age, height, weight, is_student]

# %%
friends
# Out:
# ['Romi', 'Wahyudi', 'Hasibuan']

# %%
variabel_with_list
# Out:
# ['Romi Wahyudi', 21, 165, 64.6, True]

# %%
# Tuple

friends = ("Romi", "Wahyudi", "Hasibuan")

# %%
help(friends)
# Out:
# Help on tuple object:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Built-in subclasses:
#  |      asyncgen_hooks
#  |      UnraisableHookArgs
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
# ...

# %%
# Dictionary

my_self = {
    "name": "Romi Wahyudi",
    "age": 21,
    "height": 165
}

# %%
my_self['name']
# Out:
# 'Romi Wahyudi'

# %% [markdown]
# ### **Perulangan/Looping**

# %%
for i in friends:
  print(i)
# Out:
# Romi
# Wahyudi
# Hasibuan

# %%
# perulangan dengan while

index = 0
while index < len(friends):
  print(friends[index])
  index+=1
# Out:
# Romi
# Wahyudi
# Hasibuan

# %% [markdown]
# ### **Function (Fungsi)**

# %%
def introduce(name, age, height):
  print(name)
  print(age)
  print(height)

# %%
introduce("Romi", 21, 165)
# Out:
# Romi
# 21
# 165

# %%
introduce("Hamizan", 18, 165)
# Out:
# Hamizan
# 18
# 165

# %% [markdown]
# #### **Sumber belajar**
#
# 1. Belajar bersama teman (nanya-nanya)
# 2.
# 3.
#
# Cantumkan link kalian mencari jawaban, misalnya dari stakeoverflow

# %% [markdown]
# ### **Quiz 1**

# %% [markdown]
# Buatkan sebuah function yang mempunyai parameter `name`, dan `hobi`. Function tersebut akan mengembalikan sebuah kalimat
# **nama saya `name`, saya suka `hobi`.**

# %%
def diriku(name, hobi):
  return f"Nama saya {name}, saya suka {hobi}."

# %%
diriku("Mijan", "Bermain Game")
# Out:
# 'Nama saya Mijan, saya suka Bermain Game.'

# %% [markdown]
# ### **Quiz 2**

# %% [markdown]
# Buatkan sebuah function yang akan mempunyai Parameter `name`. Fungsi ini akan mengembalikan nama kalian. Ingat gunakan `return` pada fungsi, jangan `print` langsung di dalam fungsinya. <br>
#
# Ouput dari fungsi ini adalah mengembalikan variabel `name` dalam bentuk list.
#
#
# **example**
# <br>
#
# name = Romi Wahyudi
#
# result = [Romi, Wahyudi]
#
#
# note. Jika nama kalian hanya satu kata, tambahkan "suka belajar nlp"
#
#
# kalian bisa menggunakan fungsi `split` string untuk tugas ini

# %%
def fungsiku(name):
    result = name.split() # split untuk memisahkan string berdasarkan spasi dan membuatnya menjadi list

    if len(result) == 1: # 1 karena merupakan elemen pertama bukan dihitung dari index(0)
        result.append("suka belajar nlp")
        
    return result

# %%
# masukkan fungsi pada variabel result
result = fungsiku("Mijan")
result
# Out:
# ['Mijan', 'suka belajar nlp']

# %% [markdown]
# ### **Quiz 3**

# %% [markdown]
# Dari hasil **quiz 2**. Teman teman akan membuat hasil akhir dengan variable `result` yang akan berisi function 2.
# <br>
# untuk Quiz 3, buatkan sebuah fungsi yang akan mempunyai parameter `result` tesebut.
#
# fungsi ini akan me-`return` satu kalimat bersih dengan semuanya huruf kecil
#
# 1. Kalian bisa menghilangkan emoticon terlebih dahulu
# 2. Kemudian bisa menggunakan fungsi `lower` string
#
#
# **contoh output akhir**
#
# result = romi wahyudi

# %%
def destroy(result):
  result = " ".join(result)
  result = result.replace(" ", "😂")
  return result

# %%
result = destroy(result)
result
# Out:
# 'Mijan😂suka😂belajar😂nlp'

# %%
# fungsi quiz 3 tulis disini
# membersihkan data list dengan menghapus emoji dan mengubahnya menjadi lowercase
def clean_data(result):
    result = result.replace("😂", " ")
    result = result.lower()
    return result

# %%
result = clean_data(result)
result
# Out:
# 'mijan suka belajar nlp'

# %% [markdown]
# #### **Penggunaan Generative AI tidak akan diizinkan secara official pada quiz ini. Tapi pasti kalian ngeyel kan, yaudah sok pake aja. Tapi minggu depan akan dipanggi 3 orang secara random untuk maju ke depan**
#
# <br>
#
#
# #### **Pastikan yang maju ke depan ngerti dengan apa yang dikerjakan, kalau tidak akan dinilai 0 **
#
# yang tidak memakai AI, semoga ilmunya lebih berkah dan dapat banyak pahala di bulan Ramdhan ini
